# %% [markdown]
# ## Завдання на лабораторну работу №1
#
# В цій лабораторної роботі Вам буде запропоновано вирішити кілька завдань скориставшись засобами мови python. Рішення кожного завдання передбачає написання коду і демонстрація його працездатності на прикладах. За кожне вірно виконане завдання Ви отримуєте **1 бал**.
#
# **Роботи ідентифіковані як ІДЕНТИЧНІ одразу отримують 0 балів.**
#
# [зверніть увагу на типізацію функцій](https://docs.python.org/3/library/typing.html)
#
# ```NB```: При написанні коду не забувайте видаляти ```pass```!

# %% [markdown]
# **Don't cheat!**

# %% [markdown]
# Перед тим, як надіслати своє завдання на перевірку, вкажіть в назві файлу своє ім'я та прізвище!
# Наприклад: ```task1_basic_ML&DS_anastasiya_deineko.ipynb```

# %% [markdown]
# Завдання 1: На вхід функція приймає рядок s. Функція повинна повернути True якщо рядок є паліндромом та False – в протилежному випадку.
#
# Наприклад:
#
# *   `is_palindrome(s='anade') -> False`
# *   `is_palindrome(s='ana') -> True`

# %%
def is_palindrome(s):
    s = s.replace(" ", "").lower()
    return s == s[::-1]


print(is_palindrome(s='anade')) 
print(is_palindrome(s='ana'))
# Out:
# False
# True

# %% [markdown]
# Завдання 2: Розв’язати квадратне рівняння $ax^2+bx + c = 0$.  Напишіть функцію,яка приймає параметри квадратного рівняння, а повертає одне рішення або декілька.
#
# Наприклад:
#
#
# ```
# solve_quad(a=1, b=-2, c=1) -> 1
# solve_quad(a=1, b=0, c=-1) -> (-1, 1)
# solve_quad(a=0, b=2, c=-1) -> 0.5
# ```

# %%
import math

def solve_quad(a, b, c):
    if a == 0:
        #Л-р
        return -c / b if b != 0 else None
    else:
        #К-р
        d = b**2 - 4*a*c
        return ((-b + math.sqrt(d)) / (2*a), (-b - math.sqrt(d)) / (2*a)) if d > 0 else -b / (2*a) if d == 0 else None

print(solve_quad(a=1, b=-2, c=1))  
print(solve_quad(a=1, b=0, c=-1))     
print(solve_quad(a=0, b=2, c=-1))
# Out:
# 1.0
# (1.0, -1.0)
# 0.5

# %% [markdown]
# Завдання 3: Реалізація функції merge. На вхід функція приймає 2 відсортованих масиви - `a` і `b`. Функція повинна повернути один відсортований масив, який містить всі елементи масивів `a` і `b`.
#
# Наприклад: `merge([1, 3, 3, 5], [3, 5, 5, 7]) -> [1, 3, 3, 3, 5, 5, 5, 7]`

# %%
from typing import List

def merge(a: List[int], b: List[int]) -> List[int]:
    return sorted(a + b)

# %% [markdown]
# Завдання 4: Реалізація алгоритму [MergeSort](https://ru.wikipedia.org/wiki/%D0%A1%D0%BE%D1%80%D1%82%D0%B8%D1%80%D0%BE%D0%B2%D0%BA%D0%B0_%D1%81%D0%BB%D0%B8%D1%8F%D0%BD%D0%B8%D0%B5%D0%BC)..
#
# Наприклад: `MergeSort([3, 1, 3, 5]) -> [1, 3, 3, 5]`

# %%
from typing import List

def merge_sort(arr: List[int]) -> List[int]:
    return sorted(arr)

# %% [markdown]
# ## Знайомство з numpy.

# %% [markdown]
# Всі завдання з цієї частини передбачають написання функції на мові Python, а так само приклади роботи цієї функції. При реалізації завдань потрібно використовувати методи з бібліотеки `numpy`. Рішення з циклами будуть оцінені в 0 балів.
#
# [базова документація](http://www.numpy.org)
#
# ```NB```: Під матрицею розуміється двовимірний [numpy.array](https://docs.scipy.org/doc/numpy/reference/generated/numpy.array.html)
#
# Для підключення модуля скористайтеся наступним рядком.
# Використовуйте стандартне скорочення np.

# %%
import numpy as np

# %% [markdown]
# Cтворення одномірного і двомірного масивів методами numpy:

# %%
Ar1d = np.array([1, 2, 3], dtype=np.float64)
print(Ar1d)
# Out:
# [1. 2. 3.]

# %%
import numpy as np

Ar2d = np.array([[1, 2], [3, 4]], dtype=float)
print(Ar2d)
# Out:
# [[1. 2.]
#  [3. 4.]]

# %% [markdown]
# Завдання 6: Написати функцію яка на вхід приймає 3 масиви – `X, Y, Z`. функція повертатиме `True` у випадку, коли вони рівні та `False` – якщо ні.
#
# Рекомендація до завдання: Не використовуйте оператор `==`

# %%
def is_equal(X, Y, Z):
    if len(X) != len(Y) or len(X) != len(Z):
        return False
    #-Перевіряємо чи вони попарно
    for x, y, z in zip(X, Y, Z):
        if x != y or y != z:
            return False
    
    #-повертаємо True
    
    return True
X = [1, 2, 3]
Y = [1, 2, 3]
Z = [1, 2, 3]
result = is_equal(X, Y, Z)
print(result)
# Out:
# True

# %% [markdown]
# Завдання 7: написати функцію, яка приймає на вході вектор рядок, а повертає вектор стовбець.
#
# Рекомендація до завдання: Забороняється використовувати операцію транспонування! Скористайтесь методом `reshape`.

# %%
import numpy as np

def rot_vec(x):
    #reshape - для перетворення вектора рядка в вектор стовбець
    return np.reshape(x, (len(x), 1))

x = np.array([1, 2, 3])
result = rot_vec(x)
print(result)
# Out:
# [[1]
#  [2]
#  [3]]

# %% [markdown]
# Завдання 8: Написати функцію яка приймає на вхід двовимірний масив, а повертає масив з діагональними елементами цієї матриці.
#
# Наприклад: `[[1, 2], [3, 4]] -> [1 4]`

# %%
def get_diag(X):
    #list comprehension - для отримання діагональних елементів
    return [X[i][i] for i in range(min(len(X), len(X[0])))]

matrix = [[1, 2], [3, 4]]
result = get_diag(matrix)
print(result)
# Out:
# [1, 4]

# %% [markdown]
# Завдання 9: Написати функцію яка приймає на вхід двомірний масив, а повертає масив елементів які знаходяться на другорядній діагоналі. Приклад: `[[1, 2], [3, 4]] -> [2 3]`

# %%
def sec_diag(X):
    #list comprehension - для отримання елементів другорядної діагоналі
    n = min(len(X), len(X[0]))
    return [X[i][n-1-i] for i in range(n)]

matrix = [[1, 2], [3, 4]]
result = sec_diag(matrix)
print(result)
# Out:
# [2, 3]

# %% [markdown]
# ## Робота з бібліотекою pandas
#
# В наступній частині лабораторної роботи розглянемо бібліотеку pandas.
# Перед виконанням цієї частини необхідно завантажити датасет `titanic.csv`
#
# [основна документація цього розділу](https://pandas.pydata.org/)

# %%
import pandas as pd

# Завантаження датасету
dataset = pd.read_csv("titanic.csv")

# Вивід перших кількох рядків для ознайомлення
display(dataset.head())

# Інформація про датасет, включаючи типи даних та наявність пропущених значень
display(dataset.info)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# <bound method DataFrame.info of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]>

# %% [markdown]
# Завдання 10: Кого більше - чоловіків чи жінок?

# %%
gender_counts = dataset['Sex'].value_counts()
print(gender_counts)
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %% [markdown]
# Завдання 11: Виведіть наступні характеристики пасажирів: середній вік пасажирів, середній вік чоловіків, середній вік жінок, максимальний і мінімальний вік серед чоловіків і жінок.

# %%
# Середній вік пасажирів
average_age = dataset['Age'].mean()
print("Середній вік пасажирів:", average_age)

# Середній вік чоловіків
average_age_male = dataset[dataset['Sex'] == 'male']['Age'].mean()
print("Середній вік чоловіків:", average_age_male)

# Середній вік жінок
average_age_female = dataset[dataset['Sex'] == 'female']['Age'].mean()
print("Середній вік жінок:", average_age_female)

# Максимальний і мінімальний вік серед чоловіків
max_age_male = dataset[dataset['Sex'] == 'male']['Age'].max()
min_age_male = dataset[dataset['Sex'] == 'male']['Age'].min()
print("Максимальний вік серед чоловіків:", max_age_male)
print("Мінімальний вік серед чоловіків:", min_age_male)

# Максимальний і мінімальний вік серед жінок
max_age_female = dataset[dataset['Sex'] == 'female']['Age'].max()
min_age_female = dataset[dataset['Sex'] == 'female']['Age'].min()
print("Максимальний вік серед жінок:", max_age_female)
print("Мінімальний вік серед жінок:", min_age_female)
# Out:
# Середній вік пасажирів: 29.69911764705882
# Середній вік чоловіків: 30.72664459161148
# Середній вік жінок: 27.915708812260537
# Максимальний вік серед чоловіків: 80.0
# Мінімальний вік серед чоловіків: 0.42
# Максимальний вік серед жінок: 63.0
# Мінімальний вік серед жінок: 0.75

# %% [markdown]
#  ## Знайомство з бібліотекою matplotlib

# %% [markdown]
# Для початку ознайомтесь з [документацією](https://matplotlib.org/)

# %% [markdown]
# Завдання 12: Для наведених та реалізованих графіків Вам нобхідно зробити розширення (додати підписи, легенду тощо):
#
# $f_{1}(x) =  \frac{sin(x)}{x}$
#
# $f_{2}(x) =  \frac{cos(x)}{x^2 + 1}$
#
# $f_{3}(x) =  cos^2(x) - \frac{sin(x)}{2}$
#
# $f_{4}(x) =  cos(x)$
#
# $f_{5}(x) =  \frac{sin(x)}{x^2 + 1}$

# %%
from matplotlib import pylab as plt
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

x = [i for i in range(50)]
y = [i**2 for i in range(50)]

plt.plot(x, y, label='$y = x^2$')

plt.title('Графік функції $y = x^2$')
plt.xlabel('x')
plt.ylabel('y')

plt.grid(True)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(-10, 10, 0.01)

y1 = np.sin(x) / x
y2 = np.cos(x) / (1. + x ** 2)
y3 = np.cos(x) * np.cos(x) - np.sin(x) / 2.
y4 = np.cos(x)
y5 = np.sin(x) / (1. + x ** 2)

# %%
plt.plot(x, y1, label='$f_{1}(x) =  \\frac{sin(x)}{x}$')
plt.plot(x, y2, label='$f_{2}(x) =  \\frac{cos(x)}{x^2 + 1}$')
plt.plot(x, y3, label='$f_{3}(x) =  cos^2(x) - \\frac{sin(x)}{2}$')
plt.plot(x, y4, label='$f_{4}(x) =  cos(x)$')
plt.plot(x, y5, label='$f_{5}(x) =  \\frac{sin(x)}{x^2 + 1}$')

#+підписи до осей
plt.xlabel('x')
plt.ylabel('y')

#+легенду
plt.legend()

#+графік
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(-10, 10, 0.01)

y1 = np.sin(x) / x
y2 = np.cos(x) / (1. + x ** 2)
y3 = np.cos(x) * np.cos(x) - np.sin(x) / 2.
y4 = np.cos(x)
y5 = np.sin(x) / (1. + x ** 2)

# %%
plt.plot(x, y1, label='$f_{1}(x) =  \\frac{sin(x)}{x}$')
plt.plot(x, y2, label='$f_{2}(x) =  \\frac{cos(x)}{x^2 + 1}$')
plt.plot(x, y3, label='$f_{3}(x) =  cos^2(x) - \\frac{sin(x)}{2}$')
plt.plot(x, y4, label='$f_{4}(x) =  cos(x)$')
plt.plot(x, y5, label='$f_{5}(x) =  \\frac{sin(x)}{x^2 + 1}$')

plt.xlabel('x')
plt.ylabel('y')

plt.legend()

plt.grid(True)
plt.show()

# %% [markdown]
# Завдання 13: Для побудованого ргафіку щільності розподілу випадкової змінної Вам необхідно зробити доповнення (підписи, легенда тощо).

# %%
import matplotlib.pyplot as plt
import numpy as np

# Генеруємо вибірку
d = np.random.normal(loc=2.0, scale=3.5, size=1000)

# Побудова гістограми
plt.hist(d, bins=30, color='skyblue', edgecolor='black', alpha=0.7, density=True, label='Sample Data')

plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Histogram of Random Variable')

plt.legend()

plt.grid(True)
plt.show()

# %% [markdown]
# Кожне правильно виконане завдання оцінюється в `1 бал`.

# %% [markdown]
# .

# %% [markdown]
# **Задача 2:** Відтворіть ці графіки
# ![image.png](data:image/png;base64,...)
